# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_style('whitegrid')

# %matplotlib inline
# %config InlineBackend.figure_format ='retina'

# %%
data = pd.read_csv('/Users/aishwaryachinnari/Desktop/myproj/DSI-SF-3/datasets/wine_quality/winequality-red.csv', sep = ';')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
data.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
data.shape
# Out:
# (1599, 12)

# %%
data.columns
# Out:
# Index([u'fixed acidity', u'volatile acidity', u'citric acid',
#        u'residual sugar', u'chlorides', u'free sulfur dioxide',
#        u'total sulfur dioxide', u'density', u'pH', u'sulphates', u'alcohol',
#        u'quality'],
#       dtype='object')

# %%
data['alcohol'].max()
# Out:
# 14.9

# %%
data['pH'].max()
# Out:
# 4.0099999999999998

# %%
data['residual sugar'].max()
# Out:
# 15.5

# %%
data['quality'].min()
# Out:
# 3

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# %matplotlib inline
data.alcohol.plot()

# %%
wine = pd.read_csv('/Users/aishwaryachinnari/Desktop/myproj/DSI-SF-3/datasets/wine_quality/winequality_merged.csv')

# %%
wine.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  red_wine
# 0      9.4        5         1
# ...

# %%
wine[wine.alcohol==9.4].head()
# Out:
#     fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0             7.4              0.70         0.00             1.9      0.076
# 4             7.4              0.70         0.00             1.9      0.076
# 5             7.4              0.66         0.00             1.8      0.075
# 6             7.9              0.60         0.06             1.6      0.069
# 20            8.9              0.22         0.48             1.8      0.077
#
#     free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                  11.0                  34.0   0.9978  3.51       0.56
# 4                  11.0                  34.0   0.9978  3.51       0.56
# 5                  13.0                  40.0   0.9978  3.51       0.56
# 6                  15.0                  59.0   0.9964  3.30       0.46
# 20                 29.0                  60.0   0.9968  3.39       0.53
#
#     alcohol  quality  red_wine
# 0       9.4        5         1
# ...

# %%
wine['residual sugar'].plot(kind = 'line')

# %%
wine['residual sugar'].max()
# Out:
# 65.799999999999997

# %%
wine['residual sugar'].mean()
# Out:
# 5.4432353393874156

# %%
wine.groupby("alcohol").size().plot(kind='line')
# most of the wine alcohol's amount is in the range 9-10

# %%
wine['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3, 9])

# %%
wine["alcohol"].mean()
# Out:
# 10.49180083115282

# %%
#  finding which quality of wine is peferred more 
wine['quality'].value_counts().plot(kind ='bar')
